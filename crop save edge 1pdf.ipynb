# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#img=cv2.imread('./data/png.png')
img=cv2.imread('Sheet.jpg')
plt.imshow(img);
plt.show()
img.shape
# Out:
# (7360, 4912, 3)

# %%
img1=img[2700:4100,2500:3230]
plt.imshow(img1)
plt.show()
img1.shape
# Out:
# (1400, 730, 3)

# %%
img2=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
plt.imshow(img2,cmap='gray')
plt.show()
plt.imsave('out6.png',img2)
img.shape
# Out:
# (7360, 4912, 3)

# %%
img3=cv2.Canny(img2,threshold1=30,threshold2=100)
plt.imshow(img3)
plt.show()

# %%
thresh,img4 = cv2.threshold(img2, 90, 255, cv2.THRESH_BINARY)
plt.imshow(img4,cmap='gray')
plt.show()
img4.shape
plt.imsave('out67.png',img4)
img.shape
# Out:
# (7360, 4912, 3)

# %%
i=0
#x,y=img_bin.shape
result=[]

while (i<1750):
    print(i)
    ls =[]
    j=0
    while j<935:
        if img_bin[i][j]==0:
            ls.append([i,j])
            print(i,j)
            j+=1
    result.append(ls)    
    i+=1
    
x = 0
y = -1
result = []
    for i in tqdm(img_bin):
# Out:
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_11964\1210816453.py", line 20
#     for i in tqdm(img_bin):
#     ^
# IndentationError: unexpected indent

# %%
resut
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11964\1022684337.py in <module>
# ----> 1 resut
#
# NameError: name 'resut' is not defined
